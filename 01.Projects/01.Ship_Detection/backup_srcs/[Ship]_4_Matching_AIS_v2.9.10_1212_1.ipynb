# %%
#---------------------- Header 
from easydict import EasyDict
import os
import json
args = EasyDict()

#------ image list 
i_1 = "/mnt/hdd/eric/.tmp_ipy/00.Data/AO/0-Pusan-2023-AO/K3_20231028043354_61071_09341261_L1G_PS/0-Pusan-2023-AO_16_K3_20231028043354_61071_09341261_L1G_PRGB_georeferencing_32652.png"

#------ tif list 
t_1 = "/mnt/hdd/eric/.tmp_ipy/00.Data/AO/0-Pusan-2023-AO/K3_20231028043354_61071_09341261_L1G_PS/K3_20231028043354_61071_09341261_L1G_PRGB_georeferencing_32652.tif"

#------ gpu
args.gpu_id = 0

#------ model 
args.img_path = i_1

print( '/'.join( args.img_path.split("/")[0:-1]) )
args.infer_threshold = 0.2
args.infer_threshold_showing = 0.5
source_root ='/'.join( args.img_path.split("/")[0:-1])

args.img_output = args.img_path.replace(".png" ,"_output_v5_1212.png")
args.img_output_masked = args.img_path.replace(".png" ,"_output_v5_1212_NewMasked.png")
args.img_output_scatter = args.img_path.replace(".png" ,"_output_v5_1212_Only_Scatter.png")

args.csv_output = args.img_path.replace(".png","_masked_v5_1212.csv")
args.csv_output_scatter = args.img_path.replace(".png","scatter_v5_1212.csv")

#------ Coordinates filtering function
args.txt_path = None

args.xml_path = "/mnt/hdd/eric/.tmp_ipy/00.Data/AO/0-Pusan-2023-AO/K3_20231028043354_61071_09341261_L1G_PS/K3_20231028043354_61071_09341261_L1G_Aux.xml"

#------ Map Shape 
# old mask
#args.map_path = os.path.join(source_root, "map")
#args.map_path = "/mnt/hdd/eric/.tmp_ipy/00.Data/Shape_Old"
# new mask 
args.map_path = "/mnt/hdd/eric/.tmp_ipy/00.Data/Shape_Korea_Clipped"


#------ TIF 
args.tf_path = t_1

# time 2023 05 23 04 50 50
args.year_= int( i_1 .split("/")[-2].split("_")[1][0:4])
args.month_ = int(i_1 .split("/")[-2].split("_")[1][4:6])
args.day_ = int(i_1 .split("/")[-2].split("_")[1][6:8])
hour_ = int(i_1 .split("/")[-2].split("_")[1][8:10])
args.hour_ = hour_ + 9
args.min  = int(i_1 .split("/")[-2].split("_")[1][10:12]) 
args.sec =  0
print("time : ", args.year_, args.month_, args.day_, args.hour_, args.min)

#------ AIS csv 
args.data_path = "/mnt/hdd/eric/.tmp_ipy/00.Data/AIS-CSV-NTO-AO/2차-11개/202310281300_dynamic.csv"
args.static_data_path = args.data_path.replace("_dynamic.csv","_static.csv")
args.final_merge = args.img_path.replace(".png",".csv")

# time gap
# 시각화 결과물에서 ais 좌표가 해상도가 더 높아지게 된다. 
args.time_gap_min = 5
args.time_gap_sec = False

# pixel gap 
# this is for visualization
args.pixel_gap = 200

# # latlon gap 
# # 매칭되는 박스와 ais 간의 기준 => 늘리면 R_ 데이터프레임에서 매칭 케이스가 늘어나게 된다. 
# args.latlon_gap = 0.000001

#------ Model Inference 
args.model_test = False
args.Box_Matching = True
args.png_draw_save = True


# Save EasyDict to a file
file_path = os.path.join(source_root ,"config.json" )
with open(file_path, 'w') as json_file:
    json.dump(args, json_file, indent=4)
# Out:
# /mnt/hdd/eric/.tmp_ipy/00.Data/AO/0-Pusan-2023-AO/K3_20231028043354_61071_09341261_L1G_PS
# time :  2023 10 28 13 33

# %%
from PIL import Image
Image.MAX_IMAGE_PIXELS = 933120000
from adjustText import adjust_text

# Draw image 
img_path = args.img_path
img_ = Image.open(img_path)
# Out:
# /mnt/hdd/eric/.conda/envs/8.tmp/lib/python3.8/site-packages/PIL/Image.py:3176: DecompressionBombWarning: Image size (1008521856 pixels) exceeds limit of 933120000 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
img_.size
# Out:
# (35352, 28528)

# %% [markdown]
# # 1. Model Inference

# %%
import testModule

if args.model_test:
    result = testModule.infer_model(input_file_path=args.img_path,\
                        thres=args.infer_threshold , gpu_id = 0)

# %%
#------------------------
# result save
import numpy as np
import os 
save_root = "/mnt/hdd/eric/.tmp_ipy/00.Data/Inference_results"
file_name = args.img_path.split("/")[-1].split(".")[0]+".npy"    

if args.model_test == False:
    result = np.load(os.path.join(save_root,file_name))
else:
    print("Result Saved")
    np.save(os.path.join(save_root,file_name), result)

# %% [markdown]
# # 2. AIS csv
#
# - time condition 에 맞게 filtering

# %%
import pandas as pd

df = pd.read_csv(args.data_path)

# %%
#---- current time ----#
import datetime
year_= args.year_
month_ = args.month_ 
day_ = args.day_
hour_ = args.hour_
min  = args.min
sec =  args.sec
crit_time_str = f"{year_}-{month_}-{day_} {hour_}:{min}:{sec}"
date = pd.to_datetime(crit_time_str)

#---- time condition ----#
time_gap_min = args.time_gap_min
time_gap_sec = args.time_gap_sec

earl_time = date - datetime.timedelta(minutes=time_gap_min,seconds=time_gap_sec)
post_time = date + datetime.timedelta(minutes=time_gap_min,seconds=time_gap_sec)

print("early : ",earl_time)
print("now : ",date)
print("late : ",post_time)
# Out:
# early :  2023-10-28 13:28:00
# now :  2023-10-28 13:33:00
# late :  2023-10-28 13:38:00

# %%
df.columns
# Out:
# Index(['mmsi_', 'time', 'lon_', 'lat_', 'heading_', 'turn_', 'speed_'], dtype='object')

# %%
df.columns = ['mmsi_', 'time', 'long', 'lat', 'heading_', 'turn_', 'speed_']

# %%
df
# Out:
#            mmsi_                 time        long        lat  heading_  turn_  \
# 0      440066260  2023-10-28 13:00:00  129.049983  35.120033      46.0   -0.0
# 1      440233000  2023-10-28 13:00:00  129.170682  35.022577     128.0   32.0
# 2      440130790  2023-10-28 13:00:00  129.142168  35.084848     511.0 -128.0
# 3      440120570  2023-10-28 13:00:00  128.993715  35.027598     258.0   -6.0
# 4      440546000  2023-10-28 13:00:00  128.858783  34.773983      65.0    0.0
# ...          ...                  ...         ...        ...       ...    ...
# 39299  440204350  2023-10-28 13:59:59  129.074795  35.090592     511.0 -128.0
# 39300  440110910  2023-10-28 13:59:59  129.065777  35.109070     359.0   -6.0
# 39301  440023940  2023-10-28 13:59:59  129.032077  35.091743     511.0 -128.0
# 39302  440154430  2023-10-28 13:59:59  129.204232  35.137183      41.0    0.0
# 39303  355674000  2023-10-28 13:59:59  129.044665  35.024073     220.0    2.0
#
#        speed_
# 0         0.0
# 1        32.3
# 2        10.4
# 3         6.7
# 4        11.5
# ...       ...
# 39299     0.0
# 39300     0.0
# 39301     0.0
# 39302    11.3
# 39303     2.7
#
# [39304 rows x 7 columns]

# %%
#---- filtering datetime ---# 
# 
time_ = []
for i,row in df.iterrows():
    #print(row["time"])
    time_.append( pd.to_datetime( row["time"] ) )
df["datetime"] = time_

con1 = df["datetime"] < post_time 
con2 = df["datetime"] > earl_time

#--- exec ---#
time_filter_flag = True

if time_filter_flag:
    t_df = df.loc[con1 & con2] 
    df.loc[con1 & con2]
else:
    t_df = df
    t_df

# %%
t_df
# Out:
#            mmsi_                 time        long        lat  heading_  turn_  \
# 16536  441743000  2023-10-28 13:28:01  129.257853  34.969650     256.0    0.0
# 16537  440101600  2023-10-28 13:28:01  129.081750  35.083377     511.0 -128.0
# 16538  370388000  2023-10-28 13:28:01  129.360148  35.096098     198.0   -5.0
# 16539  440148520  2023-10-28 13:28:01  129.065853  35.109188      94.0    0.0
# 16540  273443750  2023-10-28 13:28:01  129.033913  35.093552     258.0    0.0
# ...          ...                  ...         ...        ...       ...    ...
# 23640  273426890  2023-10-28 13:37:59  129.065293  35.097973      27.0    0.0
# 23641  457890000  2023-10-28 13:37:59  129.060877  35.099730     511.0 -128.0
# 23642  441067000  2023-10-28 13:37:59  129.242722  34.991862     219.0 -128.0
# 23643  440323340  2023-10-28 13:37:59  129.050907  35.119528      50.0    0.0
# 23644  440054060  2023-10-28 13:37:59  129.171855  34.939825      48.0   -2.0
#
#        speed_            datetime
# 16536    16.3 2023-10-28 13:28:01
# 16537     0.1 2023-10-28 13:28:01
# 16538    12.3 2023-10-28 13:28:01
# 16539     0.0 2023-10-28 13:28:01
# 16540     0.0 2023-10-28 13:28:01
# ...       ...                 ...
# 23640     0.0 2023-10-28 13:37:59
# 23641     0.1 2023-10-28 13:37:59
# 23642     8.6 2023-10-28 13:37:59
# 23643     0.0 2023-10-28 13:37:59
# 23644    13.2 2023-10-28 13:37:59
#
# [7109 rows x 8 columns]

# %% [markdown]
# # 3. Coordinates filtering

# %%
# Coordinates filtering function ! 

if args.txt_path != None:
    txt_path = args.txt_path
    f = open(txt_path,'r')
    lines = f.readlines()
    lines

    top_left =     lines[1]
    bottom_right = lines[-1]

    min_long = float( top_left.split(":")[1].split(",")[1][0:10] )
    max_long = float( bottom_right.split(":")[1].split(",")[1][0:10] ) 

    min_lat  = float( bottom_right.split(":")[1].split(",")[0][0:10] ) 
    max_lat  = float( top_left.split(":")[1].split(",")[0][0:10] ) 

elif args.xml_path != None:
    # XML parsing
    import xml.etree.ElementTree as ET

    xml_path = args.xml_path
    tree = ET.parse(args.xml_path)
    root = tree.getroot() 


    Top_left = []
    Bottom_right = []

    for child in root:
        if child.tag =="Image":
            print(child)
            for grand_child in child:
                if grand_child.tag =="PAN":
                    for gg_child in grand_child:
                        #print(gg_child.tag)
                        if gg_child.tag == "ImagingCoordinates":
                            for ggg in gg_child:
                                
                                if ggg.tag =="ImageGeogTL":
                                    # print(ggg.tag)                         
                                    # print(ggg[0].text)
                                    # print(ggg[1].text)
                                    Top_left.append(float(ggg[0].text))
                                    Top_left.append(float(ggg[1].text))
                                elif ggg.tag == "ImageGeogBR":
                                    # print(ggg.tag)                         
                                    # print(ggg[0].text)
                                    # print(ggg[1].text)
                                    Bottom_right.append(float(ggg[0].text))
                                    Bottom_right.append(float(ggg[1].text))
    
    min_long = Top_left[1]
    max_long = Bottom_right[1]
    min_lat = Bottom_right[0]
    max_lat = Top_left[0]

# 35.032614576
# 128.632902263
# ImageGeogBR
# 34.852878881
# 128.904069499

print(min_long,max_long,min_lat,max_lat)
# Out:
# <Element 'Image' at 0x7f298261eb80>
# 128.632902263 128.904069499 34.852878881 35.032614576

# %%
con1 = t_df["long"] > min_long
con2 = t_df["long"] < max_long

con3 = t_df["lat"] > min_lat
con4 = t_df["lat"] < max_lat + 0.0225 # debugged by eric 


#------------------------------------
location_filter_flag = True

if location_filter_flag == True:
    #q_df = df.loc[con1 & con2 & con3 & con4]
    q_df = t_df.loc[con1 & con2 & con3 & con4]
    q_df
else:
    q_df = df

# %%
q_df
# Out:
#            mmsi_                 time        long        lat  heading_  turn_  \
# 16608  440328000  2023-10-28 13:28:09  128.835178  34.941688     335.0    0.0
# 16808  440328000  2023-10-28 13:28:29  128.834753  34.942528     335.0    0.0
# 17374  440328000  2023-10-28 13:29:29  128.833485  34.945050     334.0    0.0
# 17553  440328000  2023-10-28 13:29:48  128.833087  34.945860     334.0    0.0
# 17757  440328000  2023-10-28 13:30:08  128.832667  34.946695     334.0    0.0
# 17976  440328000  2023-10-28 13:30:29  128.832225  34.947560     335.0    0.0
# 18172  440328000  2023-10-28 13:30:48  128.831827  34.948352     335.0    0.0
# 18410  440328000  2023-10-28 13:31:08  128.831383  34.949230     334.0   -0.0
# 18865  440328000  2023-10-28 13:31:48  128.830555  34.950853     334.0   -0.0
# 18916  440172660  2023-10-28 13:31:52  128.885967  34.992367     255.0    0.0
# 19614  440328000  2023-10-28 13:32:48  128.829267  34.953345     334.0    0.0
# 19617  477925100  2023-10-28 13:32:48  128.812667  34.889083     203.0    0.0
# 19864  440328000  2023-10-28 13:33:08  128.828825  34.954170     334.0    0.0
# 20039  370025000  2023-10-28 13:33:21  128.778055  34.860250     194.0    2.0
# 20146  440328000  2023-10-28 13:33:29  128.828360  34.955032     334.0   -1.0
# 20405  440328000  2023-10-28 13:33:48  128.827940  34.955807     334.0   -0.0
# 20668  440328000  2023-10-28 13:34:08  128.827465  34.956665     334.0    0.0
# 21013  440172660  2023-10-28 13:34:33  128.883795  34.992437     260.0    0.0
# 21128  440146890  2023-10-28 13:34:41  128.875793  34.936138     511.0 -128.0
# 21226  440328000  2023-10-28 13:34:48  128.826588  34.958250     334.0    0.0
# 21504  440328000  2023-10-28 13:35:08  128.826142  34.959053     334.0    0.0
# 21768  440328000  2023-10-28 13:35:29  128.825678  34.959888     334.0    1.0
# 21822  440172660  2023-10-28 13:35:33  128.882970  34.992492     260.0    0.0
# 22017  440328000  2023-10-28 13:35:48  128.825262  34.960638     335.0    0.0
# 22551  440328000  2023-10-28 13:36:29  128.824385  34.962233     335.0    1.0
# 23240  440328000  2023-10-28 13:37:28  128.823118  34.964527     335.0    0.0
#
#        speed_            datetime
# 16608     9.8 2023-10-28 13:28:09
# 16808     9.8 2023-10-28 13:28:29
# 17374     9.8 2023-10-28 13:29:29
# 17553     9.8 2023-10-28 13:29:48
# 17757     9.7 2023-10-28 13:30:08
# 17976     9.7 2023-10-28 13:30:29
# 18172     9.7 2023-10-28 13:30:48
# 18410     9.7 2023-10-28 13:31:08
# 18865     9.7 2023-10-28 13:31:48
# 18916     2.2 2023-10-28 13:31:52
# 19614     9.7 2023-10-28 13:32:48
# 19617     0.2 2023-10-28 13:32:48
# 19864     9.7 2023-10-28 13:33:08
# 20039     0.3 2023-10-28 13:33:21
# 20146     9.7 2023-10-28 13:33:29
# 20405     9.6 2023-10-28 13:33:48
# 20668     9.6 2023-10-28 13:34:08
# 21013     2.3 2023-10-28 13:34:33
# 21128     3.3 2023-10-28 13:34:41
# 21226     9.6 2023-10-28 13:34:48
# 21504     9.5 2023-10-28 13:35:08
# 21768     9.4 2023-10-28 13:35:29
# 21822     2.4 2023-10-28 13:35:33
# 22017     9.3 2023-10-28 13:35:48
# 22551     9.1 2023-10-28 13:36:29
# 23240     8.9 2023-10-28 13:37:28

# %%
import utm
import rasterio

#-------------------
# utm => pixels 
#------------------
utm_array =[] # long lat 
#--- csv 
# latlong --> utm
for lat,lon in zip(q_df['lat'].values,q_df['long'].values):
    #print(lat)
    # if lat < 80:
    res = utm.from_latlon(lat,lon,52,"N")
    utm_array.append(res)

# 전환한 utm_array 를 데이터프레임에 병합 
q_df['utm_array']= utm_array


pixels_=[] # utm_array 를 pixels_ 로 변경 
tf_path = args.tf_path
with rasterio.open(tf_path) as map_layer:

    for inp in utm_array:
    
        coords2pixels = map_layer.index(inp[0],inp[1]) #input lon,lat # 좌표계 
        pixels_.append(coords2pixels)

q_df['pixels'] = pixels_

#--- init index in q_df
q_df.drop_duplicates(inplace=True)
q_df.reset_index(inplace=True,drop=True)
# Out:
# <ipython-input-16-06a44a921bcb>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q_df['utm_array']= utm_array
# <ipython-input-16-06a44a921bcb>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q_df['pixels'] = pixels_
# <ipython-input-16-06a44a921bcb>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q_df.drop_duplicates(inplace=True)

# %%
# remove duplicate row 
[i[1:-1] for i in q_df['time']]
# pd.to_datetime( )
# Out:
# ['023-10-28 13:28:0',
#  '023-10-28 13:28:2',
#  '023-10-28 13:29:2',
#  '023-10-28 13:29:4',
#  '023-10-28 13:30:0',
#  '023-10-28 13:30:2',
#  '023-10-28 13:30:4',
#  '023-10-28 13:31:0',
#  '023-10-28 13:31:4',
#  '023-10-28 13:31:5',
#  '023-10-28 13:32:4',
#  '023-10-28 13:32:4',
#  '023-10-28 13:33:0',
#  '023-10-28 13:33:2',
#  '023-10-28 13:33:2',
#  '023-10-28 13:33:4',
#  '023-10-28 13:34:0',
#  '023-10-28 13:34:3',
#  '023-10-28 13:34:4',
#  '023-10-28 13:34:4',
#  '023-10-28 13:35:0',
#  '023-10-28 13:35:2',
#  '023-10-28 13:35:3',
#  '023-10-28 13:35:4',
#  '023-10-28 13:36:2',
#  '023-10-28 13:37:2']

# %%
q_df
# Out:
#         mmsi_                 time        long        lat  heading_  turn_  \
# 0   440328000  2023-10-28 13:28:09  128.835178  34.941688     335.0    0.0
# 1   440328000  2023-10-28 13:28:29  128.834753  34.942528     335.0    0.0
# 2   440328000  2023-10-28 13:29:29  128.833485  34.945050     334.0    0.0
# 3   440328000  2023-10-28 13:29:48  128.833087  34.945860     334.0    0.0
# 4   440328000  2023-10-28 13:30:08  128.832667  34.946695     334.0    0.0
# 5   440328000  2023-10-28 13:30:29  128.832225  34.947560     335.0    0.0
# 6   440328000  2023-10-28 13:30:48  128.831827  34.948352     335.0    0.0
# 7   440328000  2023-10-28 13:31:08  128.831383  34.949230     334.0   -0.0
# 8   440328000  2023-10-28 13:31:48  128.830555  34.950853     334.0   -0.0
# 9   440172660  2023-10-28 13:31:52  128.885967  34.992367     255.0    0.0
# 10  440328000  2023-10-28 13:32:48  128.829267  34.953345     334.0    0.0
# 11  477925100  2023-10-28 13:32:48  128.812667  34.889083     203.0    0.0
# 12  440328000  2023-10-28 13:33:08  128.828825  34.954170     334.0    0.0
# 13  370025000  2023-10-28 13:33:21  128.778055  34.860250     194.0    2.0
# 14  440328000  2023-10-28 13:33:29  128.828360  34.955032     334.0   -1.0
# 15  440328000  2023-10-28 13:33:48  128.827940  34.955807     334.0   -0.0
# 16  440328000  2023-10-28 13:34:08  128.827465  34.956665     334.0    0.0
# 17  440172660  2023-10-28 13:34:33  128.883795  34.992437     260.0    0.0
# 18  440146890  2023-10-28 13:34:41  128.875793  34.936138     511.0 -128.0
# 19  440328000  2023-10-28 13:34:48  128.826588  34.958250     334.0    0.0
# 20  440328000  2023-10-28 13:35:08  128.826142  34.959053     334.0    0.0
# 21  440328000  2023-10-28 13:35:29  128.825678  34.959888     334.0    1.0
# 22  440172660  2023-10-28 13:35:33  128.882970  34.992492     260.0    0.0
# 23  440328000  2023-10-28 13:35:48  128.825262  34.960638     335.0    0.0
# 24  440328000  2023-10-28 13:36:29  128.824385  34.962233     335.0    1.0
# 25  440328000  2023-10-28 13:37:28  128.823118  34.964527     335.0    0.0
#
#     speed_            datetime  \
# 0      9.8 2023-10-28 13:28:09
# 1      9.8 2023-10-28 13:28:29
# 2      9.8 2023-10-28 13:29:29
# 3      9.8 2023-10-28 13:29:48
# 4      9.7 2023-10-28 13:30:08
# 5      9.7 2023-10-28 13:30:29
# 6      9.7 2023-10-28 13:30:48
# 7      9.7 2023-10-28 13:31:08
# 8      9.7 2023-10-28 13:31:48
# 9      2.2 2023-10-28 13:31:52
# 10     9.7 2023-10-28 13:32:48
# 11     0.2 2023-10-28 13:32:48
# 12     9.7 2023-10-28 13:33:08
# 13     0.3 2023-10-28 13:33:21
# 14     9.7 2023-10-28 13:33:29
# 15     9.6 2023-10-28 13:33:48
# 16     9.6 2023-10-28 13:34:08
# 17     2.3 2023-10-28 13:34:33
# 18     3.3 2023-10-28 13:34:41
# 19     9.6 2023-10-28 13:34:48
# 20     9.5 2023-10-28 13:35:08
# 21     9.4 2023-10-28 13:35:29
# 22     2.4 2023-10-28 13:35:33
# 23     9.3 2023-10-28 13:35:48
# 24     9.1 2023-10-28 13:36:29
# 25     8.9 2023-10-28 13:37:28
#
#                                           utm_array          pixels
# 0   (484949.05057347036, 3866588.9155630465, 52, N)  (14436, 26333)
# 1      (484910.394947157, 3866682.131639439, 52, N)  (14303, 26278)
# 2    (484795.07239367574, 3866962.001670247, 52, N)  (13903, 26113)
# 3   (484758.87980750954, 3867051.8874851456, 52, N)  (13775, 26062)
# 4     (484720.6837359197, 3867144.549202965, 52, N)  (13643, 26007)
# 5   (484680.48520527215, 3867240.5413273484, 52, N)  (13506, 25950)
# 6    (484644.2915106249, 3867328.4315236155, 52, N)  (13380, 25898)
# 7     (484603.9144178435, 3867425.865964536, 52, N)  (13241, 25841)
# 8    (484528.6162179101, 3867605.9770527254, 52, N)  (12984, 25733)
# 9   (489593.33151830867, 3872202.5332208374, 52, N)   (6425, 32961)
# 10  (484411.48544624477, 3867882.5286201043, 52, N)  (12590, 25566)
# 11    (482882.5079564369, 3860758.909777679, 52, N)  (22756, 23384)
# 12   (484371.2858677624, 3867974.0864119683, 52, N)  (12459, 25509)
# 13   (479712.7606255913, 3857567.9585446888, 52, N)  (27309, 18861)
# 14  (484328.99420345447, 3868069.7511353046, 52, N)  (12323, 25448)
# 15    (484290.7953644984, 3868155.761087265, 52, N)  (12200, 25394)
# 16    (484247.5916322646, 3868250.984208058, 52, N)  (12064, 25332)
# 17    (489395.1234121296, 3872210.524339307, 52, N)   (6413, 32678)
# 18   (488657.1038338958, 3865968.0895874556, 52, N)  (15322, 31625)
# 19   (484167.8264483462, 3868426.8922274187, 52, N)  (11813, 25218)
# 20   (484127.2623118187, 3868516.0121143432, 52, N)  (11686, 25160)
# 21     (484085.0618248526, 3868608.68372144, 52, N)  (11553, 25100)
# 22    (489319.8409616357, 3872216.711506217, 52, N)   (6405, 32571)
# 23  (484047.22790601326, 3868691.9217493907, 52, N)  (11435, 25046)
# 24   (483967.4724339539, 3868868.9406189555, 52, N)  (11182, 24932)
# 25  (483852.25335608254, 3869123.5392740387, 52, N)  (10819, 24768)

# %%
q_df.to_csv(args.csv_output_scatter,index=False)

# %%
result[0][5][5]
# Out:
# 0.9965689

# %%
args.img_path
# Out:
# '/mnt/hdd/eric/.tmp_ipy/00.Data/AO/0-Pusan-2023-AO/K3_20231028043354_61071_09341261_L1G_PS/0-Pusan-2023-AO_16_K3_20231028043354_61071_09341261_L1G_PRGB_georeferencing_32652.png'

# %%
#------------------------------
# AIS matching with Bbox

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import pandas as pd
from PIL import Image
Image.MAX_IMAGE_PIXELS = 933120000
from adjustText import adjust_text

# Draw image 
img_path = args.img_path
img_ = Image.open(img_path)
plt.figure(figsize=(18,18))
#plt.imshow(img_)
ax = plt.gca()

# Bounding Box 
# Thresholding filtering 
bboxes_ = [] 
cnt = 0
for r in result[0]:
    if r[-1] > args.infer_threshold_showing:
        cnt+=1
        bboxes_.append(r)

#----------------------------------------------------- 
# BBox matching with AIS 

# Matched Bbox
idx_bboxes = []
x_bboxes = [] 
y_bboxes = []
width_bboxes = []
height_bboxes = []
angle_bboxes = []
prob_bboxes= []

# Matched AIS 
x_matched_ais = []
y_matched_ais = []
time_matched_ais = []
idxss_matched_ais = []
lat_matched_ais = []
long_matched_ais = []

mmsi_matched_ais = []
heading_matched_ais = []
turn_matched_ais = []
speed_matched_ais = []


# 데이터들은 q_df 써서 활용하는 것을 원칙으로 한다. 
x_ais = [i[1] for i in q_df["pixels"].values]
y_ais = [i[0] for i in q_df["pixels"].values]
lat_ais  = [i for i in q_df['lat'].values]
long_ais = [i for i in q_df['long'].values]
mmsi_ = [i for i in q_df['mmsi_'].values]
heading_ = [i for i in q_df['heading_'].values]
turn_ = [i for i in q_df['turn_'].values]
speed_ = [i for i in q_df['speed_'].values]

idx_ais = [i for i in q_df.index.values]
time_ais = [i[1:-1] for i in q_df['time']]


for bidx, box_ in enumerate( bboxes_):
    x = box_[0]
    y = box_[1]
    width =  box_[2]
    height = box_[3]
    angle_ = box_[4]
    prob_  = box_[5]
    

    # model 의 객체좌표가 center 중심인데, patches.Rectangle 은 좌하단을 기준점으로 보기 때문에. x,y 를 아래와 같이 shift 
    # roatate 할 때, 중심좌표 center 로 잡고, angle radian 변환해서 넣어주기 
    path_obj = patches.Rectangle((x-width*0.5,y-height*0.5), width, height, 
                                linewidth=0.1, edgecolor="yellow", fill=False,
                                rotation_point="center",
                                angle=angle_*180/np.pi,
                                alpha=0.35)
    
    ax.add_patch(path_obj)


    #--- find matched AIS with each box 
    cnt =0 
    for a,b,ix,t,lat_,long_,mmsi,heading,turn,speed in zip(x_ais,y_ais,idx_ais,time_ais, lat_ais,long_ais, mmsi_,heading_,turn_,speed_):
        
        # 각 bbox 범위안에 들어오는 ais 중에서 첫번쨰 ais 만 리스트에 저장 
        if cnt ==1:
            break

        # if bbox matched with ais 
        if (x - args.pixel_gap < a < x + args.pixel_gap) & (y - args.pixel_gap < b < y + args.pixel_gap) :
            
            idx_bboxes.append(bidx)
            x_bboxes.append(x)
            y_bboxes.append(y)
            width_bboxes.append(width)
            height_bboxes.append(height)
            angle_bboxes.append(angle_)
            prob_bboxes.append(prob_)

            #-- 
            x_matched_ais.append(a)
            y_matched_ais.append(b)
            time_matched_ais.append(t)
            idxss_matched_ais.append(ix)
            lat_matched_ais.append(lat_)
            long_matched_ais.append(long_)

            #-- 
            mmsi_matched_ais.append(mmsi) 
            heading_matched_ais.append(heading) 
            turn_matched_ais.append(turn) 
            speed_matched_ais.append(speed) 

            cnt+=1


#----------------------- indent over ! 
# 그렇다면 여기에서 통합된 bbox to ais csv 를 만들어버리자. 

if args.Box_Matching  == True:
    T_ = pd.DataFrame({
        "box index" : idx_bboxes,
        "bbox x coord" : x_bboxes,
        "bbox y coord" : y_bboxes,
        "bbox width" : width_bboxes,
        "bbox height" : height_bboxes,
        "bbox angle" : angle_bboxes,
        "bbox prob" : prob_bboxes,
        
        #-- ais
        "mmsi" : mmsi_matched_ais,
        "heading" : heading_matched_ais,
        "turn" : turn_matched_ais,
        "speed" : speed_matched_ais,

        "ais x coord(pixel)" : x_matched_ais,
        "ais y coord(pixel)" : y_matched_ais, 
        "ais lat"   : lat_matched_ais,
        "ais long"  : long_matched_ais,
        "ais time" : time_matched_ais
    })

    T_.drop_duplicates(inplace=True)

    S_ = {
        'box index':[i for i in range(len(bboxes_)) if i not in idx_bboxes],
        'bbox x coord' : [],
        'bbox y coord' : [],
        'bbox width' : [],
        'bbox height' : [],
        'bbox angle' :[],
        "ais x coord(pixel)" : [0 for _ in range(len([i for i in range(len(bboxes_)) if i not in idx_bboxes]))],
        "ais y coord(pixel)" : [0 for _ in range(len([i for i in range(len(bboxes_)) if i not in idx_bboxes]))],
        "ais lat"   : [0 for _ in range(len([i for i in range(len(bboxes_)) if i not in idx_bboxes]))],
        "ais long"  : [0 for _ in range(len([i for i in range(len(bboxes_)) if i not in idx_bboxes]))],
        "ais time" : [0 for _ in range(len([i for i in range(len(bboxes_)) if i not in idx_bboxes]))],
        }

    not_include_boxes = [i for i in range(len(bboxes_)) if i not in idx_bboxes]

    for a in not_include_boxes:
        box_ = bboxes_[a]
        
        S_['bbox x coord'].append(box_[0])
        S_['bbox y coord'].append(box_[1])
        S_['bbox width'].append(box_[2])
        S_['bbox height'].append(box_[3])
        S_['bbox angle'].append(box_[4])

    S_ = pd.DataFrame(S_)

    M_ = pd.concat([T_,S_])
    #del M_["box index"]
    M_.reset_index(inplace=True,drop=True)


    #----------------
    # Draw matched AIS 
    plt.scatter(x_matched_ais,y_matched_ais, alpha=0.1,color='red',marker='o',s=8)


    #--------------------------------------------
    # among the matched AIS (q_df), label and draw them 
    plt_txts = []

        
    for i,row in M_.iterrows():
        
        a = row['ais lat']
        b = row['ais long']
        c = row['mmsi']
        d = row['heading']
        e = row['turn']
        f = row['speed']
        g = row['bbox prob']

        x = row['ais x coord(pixel)']
        y = row['ais y coord(pixel)']


        if (x ==0) & (y ==0):
            x = row['bbox x coord']
            y = row['bbox y coord']
            name = f'bbox idx : {i}, No matched AIS point'

            #-- matched 가 되지 않은 박스들에는 레이블을 붙이지 않았음 
            #plt_txts.append( plt.text(x, y, name, fontsize =2,color='yellow') )

        else:
            name = f'bbox idx : {i} mmsi : {c} heading : {d} turn : {e} speed : {f} ais coord: {a,b} bbox prob : {g}'
            plt_txts.append( plt.text(x, y, name, fontsize =2,color='red') ) 


    #----------------------------------------
    # label overlap avoid 
    adjust_text(plt_txts, 
                force_points=3,
                arrowprops={'arrowstyle' : '->', 
                            'color' : 'crimson',  
                            'alpha' : 0.1}
                )
    # force_points = 3

#---------
# png save and draw
if args.png_draw_save:
    plt.imshow(img_)
    plt.savefig(args.img_output,dpi =1200 )
    plt.show()

# %%
M_
# Out:
#      box index  bbox x coord  bbox y coord  bbox width  bbox height  \
# 0            0  23330.619141  22903.722656  428.292358    77.553810
# 1            6  25393.880859  12207.528320  570.270935   122.247627
# 2          125  25515.830078  12449.001953   89.819977    29.558455
# 3          178  25500.656250  12426.394531   96.425583    27.179117
# 4          227  25477.126953  12388.470703  100.182076    37.334015
# ..         ...           ...           ...         ...          ...
# 816        816  11336.161133  24312.958984   62.913139    18.728413
# 817        817   7872.520508   5132.009766  220.183136    63.904228
# 818        818   6804.114258  26335.011719  136.307434    61.275639
# 819        819  10925.745117  14362.299805  407.076355    38.471066
# 820        820   5956.447754  16860.617188   72.740303    36.080753
#
#      bbox angle         mmsi  heading  turn  speed  ais x coord(pixel)  \
# 0     -1.222879  477925100.0    203.0   0.0    0.2               23384
# 1      1.080489  440328000.0    334.0  -1.0    9.7               25448
# 2     -0.318962  440328000.0    334.0   0.0    9.7               25566
# 3     -0.392700  440328000.0    334.0   0.0    9.7               25566
# 4     -0.210853  440328000.0    334.0   0.0    9.7               25509
# ..          ...          ...      ...   ...    ...                 ...
# 816    0.756145          NaN      NaN   NaN    NaN                   0
# 817    1.390837          NaN      NaN   NaN    NaN                   0
# 818    0.309779          NaN      NaN   NaN    NaN                   0
# 819    0.180794          NaN      NaN   NaN    NaN                   0
# 820    0.234754          NaN      NaN   NaN    NaN                   0
#
#      ais y coord(pixel)    ais lat    ais long           ais time
# 0                 22756  34.889083  128.812667  023-10-28 13:32:4
# 1                 12323  34.955032  128.828360  023-10-28 13:33:2
# 2                 12590  34.953345  128.829267  023-10-28 13:32:4
# 3                 12590  34.953345  128.829267  023-10-28 13:32:4
# 4                 12459  34.954170  128.828825  023-10-28 13:33:0
# ..                  ...        ...         ...                ...
# 816                   0   0.000000    0.000000                  0
# 817                   0   0.000000    0.000000                  0
# 818                   0   0.000000    0.000000                  0
# 819                   0   0.000000    0.000000                  0
# 820                   0   0.000000    0.000000                  0
#
# [821 rows x 15 columns]

# %%
M_.to_csv(args.csv_output)
M_[0:10]
# Out:
#    box index  bbox x coord  bbox y coord  bbox width  bbox height  bbox angle  \
# 0          0  23330.619141  22903.722656  428.292358    77.553810   -1.222879
# 1          6  25393.880859  12207.528320  570.270935   122.247627    1.080489
# 2        125  25515.830078  12449.001953   89.819977    29.558455   -0.318962
# 3        178  25500.656250  12426.394531   96.425583    27.179117   -0.392700
# 4        227  25477.126953  12388.470703  100.182076    37.334015   -0.210853
# 5        406  25279.417969  11996.823242  106.847343    63.244293   -1.313459
# 6        735  31608.117188  15333.960938   33.337345    12.645576   -0.742815
# 7          1  22203.923828  21142.089844  185.202347    36.915958    1.257369
# 8          2   8959.904297  24121.376953  317.009613    70.088814   -0.873784
# 9          3   8773.138672  23483.109375  322.878571    66.391541   -0.845356
#
#           mmsi  heading   turn  speed  ais x coord(pixel)  ais y coord(pixel)  \
# 0  477925100.0    203.0    0.0    0.2               23384               22756
# 1  440328000.0    334.0   -1.0    9.7               25448               12323
# 2  440328000.0    334.0    0.0    9.7               25566               12590
# 3  440328000.0    334.0    0.0    9.7               25566               12590
# 4  440328000.0    334.0    0.0    9.7               25509               12459
# 5  440328000.0    334.0    0.0    9.6               25332               12064
# 6  440146890.0    511.0 -128.0    3.3               31625               15322
# 7          NaN      NaN    NaN    NaN                   0                   0
# 8          NaN      NaN    NaN    NaN                   0                   0
# 9          NaN      NaN    NaN    NaN                   0                   0
#
#      ais lat    ais long           ais time
# 0  34.889083  128.812667  023-10-28 13:32:4
# 1  34.955032  128.828360  023-10-28 13:33:2
# 2  34.953345  128.829267  023-10-28 13:32:4
# 3  34.953345  128.829267  023-10-28 13:32:4
# 4  34.954170  128.828825  023-10-28 13:33:0
# 5  34.956665  128.827465  023-10-28 13:34:0
# 6  34.936138  128.875793  023-10-28 13:34:4
# 7   0.000000    0.000000                  0
# 8   0.000000    0.000000                  0
# 9   0.000000    0.000000                  0

# %%
q_df
# Out:
#         mmsi_                 time        long        lat  heading_  turn_  \
# 0   440328000  2023-10-28 13:28:09  128.835178  34.941688     335.0    0.0
# 1   440328000  2023-10-28 13:28:29  128.834753  34.942528     335.0    0.0
# 2   440328000  2023-10-28 13:29:29  128.833485  34.945050     334.0    0.0
# 3   440328000  2023-10-28 13:29:48  128.833087  34.945860     334.0    0.0
# 4   440328000  2023-10-28 13:30:08  128.832667  34.946695     334.0    0.0
# 5   440328000  2023-10-28 13:30:29  128.832225  34.947560     335.0    0.0
# 6   440328000  2023-10-28 13:30:48  128.831827  34.948352     335.0    0.0
# 7   440328000  2023-10-28 13:31:08  128.831383  34.949230     334.0   -0.0
# 8   440328000  2023-10-28 13:31:48  128.830555  34.950853     334.0   -0.0
# 9   440172660  2023-10-28 13:31:52  128.885967  34.992367     255.0    0.0
# 10  440328000  2023-10-28 13:32:48  128.829267  34.953345     334.0    0.0
# 11  477925100  2023-10-28 13:32:48  128.812667  34.889083     203.0    0.0
# 12  440328000  2023-10-28 13:33:08  128.828825  34.954170     334.0    0.0
# 13  370025000  2023-10-28 13:33:21  128.778055  34.860250     194.0    2.0
# 14  440328000  2023-10-28 13:33:29  128.828360  34.955032     334.0   -1.0
# 15  440328000  2023-10-28 13:33:48  128.827940  34.955807     334.0   -0.0
# 16  440328000  2023-10-28 13:34:08  128.827465  34.956665     334.0    0.0
# 17  440172660  2023-10-28 13:34:33  128.883795  34.992437     260.0    0.0
# 18  440146890  2023-10-28 13:34:41  128.875793  34.936138     511.0 -128.0
# 19  440328000  2023-10-28 13:34:48  128.826588  34.958250     334.0    0.0
# 20  440328000  2023-10-28 13:35:08  128.826142  34.959053     334.0    0.0
# 21  440328000  2023-10-28 13:35:29  128.825678  34.959888     334.0    1.0
# 22  440172660  2023-10-28 13:35:33  128.882970  34.992492     260.0    0.0
# 23  440328000  2023-10-28 13:35:48  128.825262  34.960638     335.0    0.0
# 24  440328000  2023-10-28 13:36:29  128.824385  34.962233     335.0    1.0
# 25  440328000  2023-10-28 13:37:28  128.823118  34.964527     335.0    0.0
#
#     speed_            datetime  \
# 0      9.8 2023-10-28 13:28:09
# 1      9.8 2023-10-28 13:28:29
# 2      9.8 2023-10-28 13:29:29
# 3      9.8 2023-10-28 13:29:48
# 4      9.7 2023-10-28 13:30:08
# 5      9.7 2023-10-28 13:30:29
# 6      9.7 2023-10-28 13:30:48
# 7      9.7 2023-10-28 13:31:08
# 8      9.7 2023-10-28 13:31:48
# 9      2.2 2023-10-28 13:31:52
# 10     9.7 2023-10-28 13:32:48
# 11     0.2 2023-10-28 13:32:48
# 12     9.7 2023-10-28 13:33:08
# 13     0.3 2023-10-28 13:33:21
# 14     9.7 2023-10-28 13:33:29
# 15     9.6 2023-10-28 13:33:48
# 16     9.6 2023-10-28 13:34:08
# 17     2.3 2023-10-28 13:34:33
# 18     3.3 2023-10-28 13:34:41
# 19     9.6 2023-10-28 13:34:48
# 20     9.5 2023-10-28 13:35:08
# 21     9.4 2023-10-28 13:35:29
# 22     2.4 2023-10-28 13:35:33
# 23     9.3 2023-10-28 13:35:48
# 24     9.1 2023-10-28 13:36:29
# 25     8.9 2023-10-28 13:37:28
#
#                                           utm_array          pixels
# 0   (484949.05057347036, 3866588.9155630465, 52, N)  (14436, 26333)
# 1      (484910.394947157, 3866682.131639439, 52, N)  (14303, 26278)
# 2    (484795.07239367574, 3866962.001670247, 52, N)  (13903, 26113)
# 3   (484758.87980750954, 3867051.8874851456, 52, N)  (13775, 26062)
# 4     (484720.6837359197, 3867144.549202965, 52, N)  (13643, 26007)
# 5   (484680.48520527215, 3867240.5413273484, 52, N)  (13506, 25950)
# 6    (484644.2915106249, 3867328.4315236155, 52, N)  (13380, 25898)
# 7     (484603.9144178435, 3867425.865964536, 52, N)  (13241, 25841)
# 8    (484528.6162179101, 3867605.9770527254, 52, N)  (12984, 25733)
# 9   (489593.33151830867, 3872202.5332208374, 52, N)   (6425, 32961)
# 10  (484411.48544624477, 3867882.5286201043, 52, N)  (12590, 25566)
# 11    (482882.5079564369, 3860758.909777679, 52, N)  (22756, 23384)
# 12   (484371.2858677624, 3867974.0864119683, 52, N)  (12459, 25509)
# 13   (479712.7606255913, 3857567.9585446888, 52, N)  (27309, 18861)
# 14  (484328.99420345447, 3868069.7511353046, 52, N)  (12323, 25448)
# 15    (484290.7953644984, 3868155.761087265, 52, N)  (12200, 25394)
# 16    (484247.5916322646, 3868250.984208058, 52, N)  (12064, 25332)
# 17    (489395.1234121296, 3872210.524339307, 52, N)   (6413, 32678)
# 18   (488657.1038338958, 3865968.0895874556, 52, N)  (15322, 31625)
# 19   (484167.8264483462, 3868426.8922274187, 52, N)  (11813, 25218)
# 20   (484127.2623118187, 3868516.0121143432, 52, N)  (11686, 25160)
# 21     (484085.0618248526, 3868608.68372144, 52, N)  (11553, 25100)
# 22    (489319.8409616357, 3872216.711506217, 52, N)   (6405, 32571)
# 23  (484047.22790601326, 3868691.9217493907, 52, N)  (11435, 25046)
# 24   (483967.4724339539, 3868868.9406189555, 52, N)  (11182, 24932)
# 25  (483852.25335608254, 3869123.5392740387, 52, N)  (10819, 24768)

# %%
# Scatter Only 
# AIS 

plt.figure(figsize=(18,18))
plt.imshow(img_)
plt.scatter([i[1] for i in q_df['pixels']],[i[0] for i in q_df['pixels']], color='red',marker='o',s=8)

plt.savefig(args.img_output_scatter,dpi =800)
plt.show()

# %% [markdown]
# # Masking BBox in the land

# %%
args.map_path
os.path.exists(args.map_path)
# Out:
# True

# %%
# Visualize Shape File !!
import geopandas as gpd
from shapely.geometry import Point
# Masking을 위한 shape 불러오기 
gdf=gpd.GeoDataFrame.from_file(args.map_path) #shapefile 불러오기

gpd.GeoSeries(gdf['geometry']).plot(figsize=(20,12)) #shapefile 플랏
# Out:
# ------------------- Eric Edited
# <Axes: >

# %%
import geopandas as gpd
from shapely.geometry import Point
# Masking을 위한 shape 불러오기 
gdf=gpd.GeoDataFrame.from_file(args.map_path) #shapefile 불러오기

# from pixel to utm
tmp_ =[] 
with rasterio.open(tf_path) as map_layer:
    for x,y in zip(M_['bbox x coord'].values, M_['bbox y coord'].values):
        
        x_coord,y_coord = map_layer.xy(y,x) # 여기 순서에 맞춰줘야, long,lat 좌표계가 맞음 
        tmp_.append([x_coord,y_coord])

tmp_1= []
ship_idxs = []
# from utm to latlon 
for idx,co in enumerate(tmp_):
    x,y = co[0],co[1]
    lat,lon = utm.to_latlon(x,y,52,"N")
    # print(lat,lon) # M_ 에서, 미리 설정되었던 AIS와 함께 좌표값 검증하였음

    print("progress : ", idx, " / ",len(tmp_))
    check=gdf['geometry'].contains(Point(lon,lat)) #특정 좌표 (long,lat)이 shapefile 다각형에 포함되는지 확인하기
    checkt=np.where(check == True)[0]
    
    if len(checkt) == 0:
        tmp_1.append(checkt)
        ship_idxs.append(idx)
# Out:
# progress :  0  /  821
# progress :  1  /  821
# progress :  2  /  821
# progress :  3  /  821
# progress :  4  /  821
# progress :  5  /  821
# progress :  6  /  821
# progress :  7  /  821
# progress :  8  /  821
# progress :  9  /  821
# progress :  10  /  821
# progress :  11  /  821
# progress :  12  /  821
# progress :  13  /  821
# progress :  14  /  821
# progress :  15  /  821
# progress :  16  /  821
# progress :  17  /  821
# progress :  18  /  821
# progress :  19  /  821
# progress :  20  /  821
# progress :  21  /  821
# progress :  22  /  821
# progress :  23  /  821
# progress :  24  /  821
# progress :  25  /  821
# progress :  26  /  821
# progress :  27  /  821
# progress :  28  /  821
# progress :  29  /  821
# progress :  30  /  821
# progress :  31  /  821
# progress :  32  /  821
# progress :  33  /  821
# progress :  34  /  821
# progress :  35  /  821
# progress :  36  /  821
# progress :  37  /  821
# progress :  38  /  821
# progress :  39  /  821
# progress :  40  /  821
# progress :  41  /  821
# progress :  42  /  821
# progress :  43  /  821
# progress :  44  /  821
# progress :  45  /  821
# progress :  46  /  821
# progress :  47  /  821
# progress :  48  /  821
# progress :  49  /  821
# progress :  50  /  821
# progress :  51  /  821
# progress :  52  /  821
# progress :  53  /  821
# progress :  54  /  821
# progress :  55  /  821
# progress :  56  /  821
# progress :  57  /  821
# progress :  58  /  821
# progress :  59  /  821
# progress :  60  /  821
# progress :  61  /  821
# progress :  62  /  821
# progress :  63  /  821
# progress :  64  /  821
# progress :  65  /  821
# progress :  66  /  821
# progress :  67  /  821
# progress :  68  /  821
# progress :  69  /  821
# progress :  70  /  821
# progress :  71  /  821
# progress :  72  /  821
# progress :  73  /  821
# progress :  74  /  821
# progress :  75  /  821
# progress :  76  /  821
# progress :  77  /  821
# progress :  78  /  821
# progress :  79  /  821
# progress :  80  /  821
# progress :  81  /  821
# progress :  82  /  821
# progress :  83  /  821
# progress :  84  /  821
# progress :  85  /  821
# progress :  86  /  821
# progress :  87  /  821
# progress :  88  /  821
# progress :  89  /  821
# progress :  90  /  821
# progress :  91  /  821
# progress :  92  /  821
# progress :  93  /  821
# progress :  94  /  821
# progress :  95  /  821
# progress :  96  /  821
# progress :  97  /  821
# progress :  98  /  821
# progress :  99  /  821
# progress :  100  /  821
# progress :  101  /  821
# progress :  102  /  821
# progress :  103  /  821
# progress :  104  /  821
# progress :  105  /  821
# progress :  106  /  821
# progress :  107  /  821
# progress :  108  /  821
# progress :  109  /  821
# progress :  110  /  821
# progress :  111  /  821
# progress :  112  /  821
# progress :  113  /  821
# progress :  114  /  821
# progress :  115  /  821
# progress :  116  /  821
# progress :  117  /  821
# progress :  118  /  821
# progress :  119  /  821
# progress :  120  /  821
# progress :  121  /  821
# progress :  122  /  821
# progress :  123  /  821
# progress :  124  /  821
# progress :  125  /  821
# progress :  126  /  821
# progress :  127  /  821
# progress :  128  /  821
# progress :  129  /  821
# progress :  130  /  821
# progress :  131  /  821
# progress :  132  /  821
# progress :  133  /  821
# progress :  134  /  821
# progress :  135  /  821
# progress :  136  /  821
# progress :  137  /  821
# progress :  138  /  821
# progress :  139  /  821
# progress :  140  /  821
# progress :  141  /  821
# progress :  142  /  821
# progress :  143  /  821
# progress :  144  /  821
# progress :  145  /  821
# progress :  146  /  821
# progress :  147  /  821
# progress :  148  /  821
# progress :  149  /  821
# progress :  150  /  821
# progress :  151  /  821
# progress :  152  /  821
# progress :  153  /  821
# progress :  154  /  821
# progress :  155  /  821
# progress :  156  /  821
# progress :  157  /  821
# progress :  158  /  821
# progress :  159  /  821
# progress :  160  /  821
# progress :  161  /  821
# progress :  162  /  821
# progress :  163  /  821
# progress :  164  /  821
# progress :  165  /  821
# progress :  166  /  821
# progress :  167  /  821
# progress :  168  /  821
# progress :  169  /  821
# progress :  170  /  821
# progress :  171  /  821
# progress :  172  /  821
# progress :  173  /  821
# progress :  174  /  821
# progress :  175  /  821
# progress :  176  /  821
# progress :  177  /  821
# progress :  178  /  821
# progress :  179  /  821
# progress :  180  /  821
# progress :  181  /  821
# progress :  182  /  821
# progress :  183  /  821
# progress :  184  /  821
# progress :  185  /  821
# progress :  186  /  821
# progress :  187  /  821
# progress :  188  /  821
# progress :  189  /  821
# progress :  190  /  821
# progress :  191  /  821
# progress :  192  /  821
# progress :  193  /  821
# progress :  194  /  821
# progress :  195  /  821
# progress :  196  /  821
# progress :  197  /  821
# progress :  198  /  821
# progress :  199  /  821
# progress :  200  /  821
# progress :  201  /  821
# progress :  202  /  821
# progress :  203  /  821
# progress :  204  /  821
# progress :  205  /  821
# progress :  206  /  821
# progress :  207  /  821
# progress :  208  /  821
# progress :  209  /  821
# progress :  210  /  821
# progress :  211  /  821
# progress :  212  /  821
# progress :  213  /  821
# progress :  214  /  821
# progress :  215  /  821
# progress :  216  /  821
# progress :  217  /  821
# progress :  218  /  821
# progress :  219  /  821
# progress :  220  /  821
# progress :  221  /  821
# progress :  222  /  821
# progress :  223  /  821
# progress :  224  /  821
# progress :  225  /  821
# progress :  226  /  821
# progress :  227  /  821
# progress :  228  /  821
# progress :  229  /  821
# progress :  230  /  821
# progress :  231  /  821
# progress :  232  /  821
# progress :  233  /  821
# progress :  234  /  821
# progress :  235  /  821
# progress :  236  /  821
# progress :  237  /  821
# progress :  238  /  821
# progress :  239  /  821
# progress :  240  /  821
# progress :  241  /  821
# progress :  242  /  821
# progress :  243  /  821
# progress :  244  /  821
# progress :  245  /  821
# progress :  246  /  821
# progress :  247  /  821
# progress :  248  /  821
# progress :  249  /  821
# progress :  250  /  821
# progress :  251  /  821
# progress :  252  /  821
# progress :  253  /  821
# progress :  254  /  821
# progress :  255  /  821
# progress :  256  /  821
# progress :  257  /  821
# progress :  258  /  821
# progress :  259  /  821
# progress :  260  /  821
# progress :  261  /  821
# progress :  262  /  821
# progress :  263  /  821
# progress :  264  /  821
# progress :  265  /  821
# progress :  266  /  821
# progress :  267  /  821
# progress :  268  /  821
# progress :  269  /  821
# progress :  270  /  821
# progress :  271  /  821
# progress :  272  /  821
# progress :  273  /  821
# progress :  274  /  821
# progress :  275  /  821
# progress :  276  /  821
# progress :  277  /  821
# progress :  278  /  821
# progress :  279  /  821
# progress :  280  /  821
# progress :  281  /  821
# progress :  282  /  821
# progress :  283  /  821
# progress :  284  /  821
# progress :  285  /  821
# progress :  286  /  821
# progress :  287  /  821
# progress :  288  /  821
# progress :  289  /  821
# progress :  290  /  821
# progress :  291  /  821
# progress :  292  /  821
# progress :  293  /  821
# progress :  294  /  821
# progress :  295  /  821
# progress :  296  /  821
# progress :  297  /  821
# progress :  298  /  821
# progress :  299  /  821
# progress :  300  /  821
# progress :  301  /  821
# progress :  302  /  821
# progress :  303  /  821
# progress :  304  /  821
# progress :  305  /  821
# progress :  306  /  821
# progress :  307  /  821
# progress :  308  /  821
# progress :  309  /  821
# progress :  310  /  821
# progress :  311  /  821
# progress :  312  /  821
# progress :  313  /  821
# progress :  314  /  821
# progress :  315  /  821
# progress :  316  /  821
# progress :  317  /  821
# progress :  318  /  821
# progress :  319  /  821
# progress :  320  /  821
# progress :  321  /  821
# progress :  322  /  821
# progress :  323  /  821
# progress :  324  /  821
# progress :  325  /  821
# progress :  326  /  821
# progress :  327  /  821
# progress :  328  /  821
# progress :  329  /  821
# progress :  330  /  821
# progress :  331  /  821
# progress :  332  /  821
# progress :  333  /  821
# progress :  334  /  821
# progress :  335  /  821
# progress :  336  /  821
# progress :  337  /  821
# progress :  338  /  821
# progress :  339  /  821
# progress :  340  /  821
# progress :  341  /  821
# progress :  342  /  821
# progress :  343  /  821
# progress :  344  /  821
# progress :  345  /  821
# progress :  346  /  821
# progress :  347  /  821
# progress :  348  /  821
# progress :  349  /  821
# progress :  350  /  821
# progress :  351  /  821
# progress :  352  /  821
# progress :  353  /  821
# progress :  354  /  821
# progress :  355  /  821
# progress :  356  /  821
# progress :  357  /  821
# progress :  358  /  821
# progress :  359  /  821
# progress :  360  /  821
# progress :  361  /  821
# progress :  362  /  821
# progress :  363  /  821
# progress :  364  /  821
# progress :  365  /  821
# progress :  366  /  821
# progress :  367  /  821
# progress :  368  /  821
# progress :  369  /  821
# progress :  370  /  821
# progress :  371  /  821
# progress :  372  /  821
# progress :  373  /  821
# progress :  374  /  821
# progress :  375  /  821
# progress :  376  /  821
# progress :  377  /  821
# progress :  378  /  821
# progress :  379  /  821
# progress :  380  /  821
# progress :  381  /  821
# progress :  382  /  821
# progress :  383  /  821
# progress :  384  /  821
# progress :  385  /  821
# progress :  386  /  821
# progress :  387  /  821
# progress :  388  /  821
# progress :  389  /  821
# progress :  390  /  821
# progress :  391  /  821
# progress :  392  /  821
# progress :  393  /  821
# progress :  394  /  821
# progress :  395  /  821
# progress :  396  /  821
# progress :  397  /  821
# progress :  398  /  821
# progress :  399  /  821
# progress :  400  /  821
# progress :  401  /  821
# progress :  402  /  821
# progress :  403  /  821
# progress :  404  /  821
# progress :  405  /  821
# progress :  406  /  821
# progress :  407  /  821
# progress :  408  /  821
# progress :  409  /  821
# progress :  410  /  821
# progress :  411  /  821
# progress :  412  /  821
# progress :  413  /  821
# progress :  414  /  821
# progress :  415  /  821
# progress :  416  /  821
# progress :  417  /  821
# progress :  418  /  821
# progress :  419  /  821
# progress :  420  /  821
# progress :  421  /  821
# progress :  422  /  821
# progress :  423  /  821
# progress :  424  /  821
# progress :  425  /  821
# progress :  426  /  821
# progress :  427  /  821
# progress :  428  /  821
# progress :  429  /  821
# progress :  430  /  821
# progress :  431  /  821
# progress :  432  /  821
# progress :  433  /  821
# progress :  434  /  821
# progress :  435  /  821
# progress :  436  /  821
# progress :  437  /  821
# progress :  438  /  821
# progress :  439  /  821
# progress :  440  /  821
# progress :  441  /  821
# progress :  442  /  821
# progress :  443  /  821
# progress :  444  /  821
# progress :  445  /  821
# progress :  446  /  821
# progress :  447  /  821
# progress :  448  /  821
# progress :  449  /  821
# progress :  450  /  821
# progress :  451  /  821
# progress :  452  /  821
# progress :  453  /  821
# progress :  454  /  821
# progress :  455  /  821
# progress :  456  /  821
# progress :  457  /  821
# progress :  458  /  821
# progress :  459  /  821
# progress :  460  /  821
# progress :  461  /  821
# progress :  462  /  821
# progress :  463  /  821
# progress :  464  /  821
# progress :  465  /  821
# progress :  466  /  821
# progress :  467  /  821
# progress :  468  /  821
# progress :  469  /  821
# progress :  470  /  821
# progress :  471  /  821
# progress :  472  /  821
# progress :  473  /  821
# progress :  474  /  821
# progress :  475  /  821
# progress :  476  /  821
# progress :  477  /  821
# progress :  478  /  821
# progress :  479  /  821
# progress :  480  /  821
# progress :  481  /  821
# progress :  482  /  821
# progress :  483  /  821
# progress :  484  /  821
# progress :  485  /  821
# progress :  486  /  821
# progress :  487  /  821
# progress :  488  /  821
# progress :  489  /  821
# progress :  490  /  821
# progress :  491  /  821
# progress :  492  /  821
# progress :  493  /  821
# progress :  494  /  821
# progress :  495  /  821
# progress :  496  /  821
# progress :  497  /  821
# progress :  498  /  821
# progress :  499  /  821
# progress :  500  /  821
# progress :  501  /  821
# progress :  502  /  821
# progress :  503  /  821
# progress :  504  /  821
# progress :  505  /  821
# progress :  506  /  821
# progress :  507  /  821
# progress :  508  /  821
# progress :  509  /  821
# progress :  510  /  821
# progress :  511  /  821
# progress :  512  /  821
# progress :  513  /  821
# progress :  514  /  821
# progress :  515  /  821
# progress :  516  /  821
# progress :  517  /  821
# progress :  518  /  821
# progress :  519  /  821
# progress :  520  /  821
# progress :  521  /  821
# progress :  522  /  821
# progress :  523  /  821
# progress :  524  /  821
# progress :  525  /  821
# progress :  526  /  821
# progress :  527  /  821
# progress :  528  /  821
# progress :  529  /  821
# progress :  530  /  821
# progress :  531  /  821
# progress :  532  /  821
# progress :  533  /  821
# progress :  534  /  821
# progress :  535  /  821
# progress :  536  /  821
# progress :  537  /  821
# progress :  538  /  821
# progress :  539  /  821
# progress :  540  /  821
# progress :  541  /  821
# progress :  542  /  821
# progress :  543  /  821
# progress :  544  /  821
# progress :  545  /  821
# progress :  546  /  821
# progress :  547  /  821
# progress :  548  /  821
# progress :  549  /  821
# progress :  550  /  821
# progress :  551  /  821
# progress :  552  /  821
# progress :  553  /  821
# progress :  554  /  821
# progress :  555  /  821
# progress :  556  /  821
# progress :  557  /  821
# progress :  558  /  821
# progress :  559  /  821
# progress :  560  /  821
# progress :  561  /  821
# progress :  562  /  821
# progress :  563  /  821
# progress :  564  /  821
# progress :  565  /  821
# progress :  566  /  821
# progress :  567  /  821
# progress :  568  /  821
# progress :  569  /  821
# progress :  570  /  821
# progress :  571  /  821
# progress :  572  /  821
# progress :  573  /  821
# progress :  574  /  821
# progress :  575  /  821
# progress :  576  /  821
# progress :  577  /  821
# progress :  578  /  821
# progress :  579  /  821
# progress :  580  /  821
# progress :  581  /  821
# progress :  582  /  821
# progress :  583  /  821
# progress :  584  /  821
# progress :  585  /  821
# progress :  586  /  821
# progress :  587  /  821
# progress :  588  /  821
# progress :  589  /  821
# progress :  590  /  821
# progress :  591  /  821
# progress :  592  /  821
# progress :  593  /  821
# progress :  594  /  821
# progress :  595  /  821
# progress :  596  /  821
# progress :  597  /  821
# progress :  598  /  821
# progress :  599  /  821
# progress :  600  /  821
# progress :  601  /  821
# progress :  602  /  821
# progress :  603  /  821
# progress :  604  /  821
# progress :  605  /  821
# progress :  606  /  821
# progress :  607  /  821
# progress :  608  /  821
# progress :  609  /  821
# progress :  610  /  821
# progress :  611  /  821
# progress :  612  /  821
# progress :  613  /  821
# progress :  614  /  821
# progress :  615  /  821
# progress :  616  /  821
# progress :  617  /  821
# progress :  618  /  821
# progress :  619  /  821
# progress :  620  /  821
# progress :  621  /  821
# progress :  622  /  821
# progress :  623  /  821
# progress :  624  /  821
# progress :  625  /  821
# progress :  626  /  821
# progress :  627  /  821
# progress :  628  /  821
# progress :  629  /  821
# progress :  630  /  821
# progress :  631  /  821
# progress :  632  /  821
# progress :  633  /  821
# progress :  634  /  821
# progress :  635  /  821
# progress :  636  /  821
# progress :  637  /  821
# progress :  638  /  821
# progress :  639  /  821
# progress :  640  /  821
# progress :  641  /  821
# progress :  642  /  821
# progress :  643  /  821
# progress :  644  /  821
# progress :  645  /  821
# progress :  646  /  821
# progress :  647  /  821
# progress :  648  /  821
# progress :  649  /  821
# progress :  650  /  821
# progress :  651  /  821
# progress :  652  /  821
# progress :  653  /  821
# progress :  654  /  821
# progress :  655  /  821
# progress :  656  /  821
# progress :  657  /  821
# progress :  658  /  821
# progress :  659  /  821
# progress :  660  /  821
# progress :  661  /  821
# progress :  662  /  821
# progress :  663  /  821
# progress :  664  /  821
# progress :  665  /  821
# progress :  666  /  821
# progress :  667  /  821
# progress :  668  /  821
# progress :  669  /  821
# progress :  670  /  821
# progress :  671  /  821
# progress :  672  /  821
# progress :  673  /  821
# progress :  674  /  821
# progress :  675  /  821
# progress :  676  /  821
# progress :  677  /  821
# progress :  678  /  821
# progress :  679  /  821
# progress :  680  /  821
# progress :  681  /  821
# progress :  682  /  821
# progress :  683  /  821
# progress :  684  /  821
# progress :  685  /  821
# progress :  686  /  821
# progress :  687  /  821
# progress :  688  /  821
# progress :  689  /  821
# progress :  690  /  821
# progress :  691  /  821
# progress :  692  /  821
# progress :  693  /  821
# progress :  694  /  821
# progress :  695  /  821
# progress :  696  /  821
# progress :  697  /  821
# progress :  698  /  821
# progress :  699  /  821
# progress :  700  /  821
# progress :  701  /  821
# progress :  702  /  821
# progress :  703  /  821
# progress :  704  /  821
# progress :  705  /  821
# progress :  706  /  821
# progress :  707  /  821
# progress :  708  /  821
# progress :  709  /  821
# progress :  710  /  821
# progress :  711  /  821
# progress :  712  /  821
# progress :  713  /  821
# progress :  714  /  821
# progress :  715  /  821
# progress :  716  /  821
# progress :  717  /  821
# progress :  718  /  821
# progress :  719  /  821
# progress :  720  /  821
# progress :  721  /  821
# progress :  722  /  821
# progress :  723  /  821
# progress :  724  /  821
# progress :  725  /  821
# progress :  726  /  821
# progress :  727  /  821
# progress :  728  /  821
# progress :  729  /  821
# progress :  730  /  821
# progress :  731  /  821
# progress :  732  /  821
# progress :  733  /  821
# progress :  734  /  821
# progress :  735  /  821
# progress :  736  /  821
# progress :  737  /  821
# progress :  738  /  821
# progress :  739  /  821
# progress :  740  /  821
# progress :  741  /  821
# progress :  742  /  821
# progress :  743  /  821
# progress :  744  /  821
# progress :  745  /  821
# progress :  746  /  821
# progress :  747  /  821
# progress :  748  /  821
# progress :  749  /  821
# progress :  750  /  821
# progress :  751  /  821
# progress :  752  /  821
# progress :  753  /  821
# progress :  754  /  821
# progress :  755  /  821
# progress :  756  /  821
# progress :  757  /  821
# progress :  758  /  821
# progress :  759  /  821
# progress :  760  /  821
# progress :  761  /  821
# progress :  762  /  821
# progress :  763  /  821
# progress :  764  /  821
# progress :  765  /  821
# progress :  766  /  821
# progress :  767  /  821
# progress :  768  /  821
# progress :  769  /  821
# progress :  770  /  821
# progress :  771  /  821
# progress :  772  /  821
# progress :  773  /  821
# progress :  774  /  821
# progress :  775  /  821
# progress :  776  /  821
# progress :  777  /  821
# progress :  778  /  821
# progress :  779  /  821
# progress :  780  /  821
# progress :  781  /  821
# progress :  782  /  821
# progress :  783  /  821
# progress :  784  /  821
# progress :  785  /  821
# progress :  786  /  821
# progress :  787  /  821
# progress :  788  /  821
# progress :  789  /  821
# progress :  790  /  821
# progress :  791  /  821
# progress :  792  /  821
# progress :  793  /  821
# progress :  794  /  821
# progress :  795  /  821
# progress :  796  /  821
# progress :  797  /  821
# progress :  798  /  821
# progress :  799  /  821
# progress :  800  /  821
# progress :  801  /  821
# progress :  802  /  821
# progress :  803  /  821
# progress :  804  /  821
# progress :  805  /  821
# progress :  806  /  821
# progress :  807  /  821
# progress :  808  /  821
# progress :  809  /  821
# progress :  810  /  821
# progress :  811  /  821
# progress :  812  /  821
# progress :  813  /  821
# progress :  814  /  821
# progress :  815  /  821
# progress :  816  /  821
# progress :  817  /  821
# progress :  818  /  821
# progress :  819  /  821
# progress :  820  /  821

# %%
# 마스킹하기 전, 탐색된 선박수
display(M_)
# Out:
#      box index  bbox x coord  bbox y coord  bbox width  bbox height  \
# 0            0  23330.619141  22903.722656  428.292358    77.553810
# 1            6  25393.880859  12207.528320  570.270935   122.247627
# 2          125  25515.830078  12449.001953   89.819977    29.558455
# 3          178  25500.656250  12426.394531   96.425583    27.179117
# 4          227  25477.126953  12388.470703  100.182076    37.334015
# ..         ...           ...           ...         ...          ...
# 816        816  11336.161133  24312.958984   62.913139    18.728413
# 817        817   7872.520508   5132.009766  220.183136    63.904228
# 818        818   6804.114258  26335.011719  136.307434    61.275639
# 819        819  10925.745117  14362.299805  407.076355    38.471066
# 820        820   5956.447754  16860.617188   72.740303    36.080753
#
#      bbox angle         mmsi  heading  turn  speed  ais x coord(pixel)  \
# 0     -1.222879  477925100.0    203.0   0.0    0.2               23384
# 1      1.080489  440328000.0    334.0  -1.0    9.7               25448
# 2     -0.318962  440328000.0    334.0   0.0    9.7               25566
# 3     -0.392700  440328000.0    334.0   0.0    9.7               25566
# 4     -0.210853  440328000.0    334.0   0.0    9.7               25509
# ..          ...          ...      ...   ...    ...                 ...
# 816    0.756145          NaN      NaN   NaN    NaN                   0
# 817    1.390837          NaN      NaN   NaN    NaN                   0
# 818    0.309779          NaN      NaN   NaN    NaN                   0
# 819    0.180794          NaN      NaN   NaN    NaN                   0
# 820    0.234754          NaN      NaN   NaN    NaN                   0
#
#      ais y coord(pixel)    ais lat    ais long           ais time
# 0                 22756  34.889083  128.812667  023-10-28 13:32:4
# 1                 12323  34.955032  128.828360  023-10-28 13:33:2
# 2                 12590  34.953345  128.829267  023-10-28 13:32:4
# 3                 12590  34.953345  128.829267  023-10-28 13:32:4
# 4                 12459  34.954170  128.828825  023-10-28 13:33:0
# ..                  ...        ...         ...                ...
# 816                   0   0.000000    0.000000                  0
# 817                   0   0.000000    0.000000                  0
# 818                   0   0.000000    0.000000                  0
# 819                   0   0.000000    0.000000                  0
# 820                   0   0.000000    0.000000                  0
#
# [821 rows x 15 columns]

# %%
# visualize the result 
M_masked = M_.iloc[ship_idxs]
# sav the csv 
M_masked.to_csv(args.csv_output)
display(M_masked)
# Out:
#      box index  bbox x coord  bbox y coord  bbox width  bbox height  \
# 0            0  23330.619141  22903.722656  428.292358    77.553810
# 1            6  25393.880859  12207.528320  570.270935   122.247627
# 2          125  25515.830078  12449.001953   89.819977    29.558455
# 3          178  25500.656250  12426.394531   96.425583    27.179117
# 4          227  25477.126953  12388.470703  100.182076    37.334015
# ..         ...           ...           ...         ...          ...
# 799        799  11108.813477  11464.345703   38.547874    28.573311
# 800        800  13917.785156  23068.167969  104.198822    17.978399
# 804        804  13492.958008  26770.533203   23.133299    11.264542
# 811        811   1817.092529  11029.329102   43.104858    24.197611
# 815        815  25113.439453   3266.494873   97.641418    27.864517
#
#      bbox angle         mmsi  heading  turn  speed  ais x coord(pixel)  \
# 0     -1.222879  477925100.0    203.0   0.0    0.2               23384
# 1      1.080489  440328000.0    334.0  -1.0    9.7               25448
# 2     -0.318962  440328000.0    334.0   0.0    9.7               25566
# 3     -0.392700  440328000.0    334.0   0.0    9.7               25566
# 4     -0.210853  440328000.0    334.0   0.0    9.7               25509
# ..          ...          ...      ...   ...    ...                 ...
# 799   -0.068231          NaN      NaN   NaN    NaN                   0
# 800    1.543596          NaN      NaN   NaN    NaN                   0
# 804    0.595508          NaN      NaN   NaN    NaN                   0
# 811   -0.376948          NaN      NaN   NaN    NaN                   0
# 815   -1.297687          NaN      NaN   NaN    NaN                   0
#
#      ais y coord(pixel)    ais lat    ais long           ais time
# 0                 22756  34.889083  128.812667  023-10-28 13:32:4
# 1                 12323  34.955032  128.828360  023-10-28 13:33:2
# 2                 12590  34.953345  128.829267  023-10-28 13:32:4
# 3                 12590  34.953345  128.829267  023-10-28 13:32:4
# 4                 12459  34.954170  128.828825  023-10-28 13:33:0
# ..                  ...        ...         ...                ...
# 799                   0   0.000000    0.000000                  0
# 800                   0   0.000000    0.000000                  0
# 804                   0   0.000000    0.000000                  0
# 811                   0   0.000000    0.000000                  0
# 815                   0   0.000000    0.000000                  0
#
# [232 rows x 15 columns]

# %% [markdown]
# # Masked Visualization

# %%
# visualize the result with masking 
# original image 
img_path = args.img_path
img_ = Image.open(img_path)

plt.figure(figsize=(18,18))
plt.imshow(img_)
ax = plt.gca()

#------------------------------------
# Bbox 
bboxes_ = [] 
cnt = 0
box_cnt = 0


# M_masked
for i,row in M_masked.iterrows():
    x = row['bbox x coord']
    y = row['bbox y coord']
    width = row['bbox width']
    height = row['bbox height']
    angle_ = row['bbox angle']
    
    box_cnt+=1
    print(f"#-------------- {box_cnt / len(M_masked):.4f}")
    path_obj = patches.Rectangle((x-width*0.5,y-height*0.5), width, height, linewidth=0.1, edgecolor="red", fill=False,
                                rotation_point="center",
                                angle=angle_*180/np.pi)
    
    ax.add_patch(path_obj)
#------------------------------------


plt.savefig(args.img_output_masked,dpi =1200 )
plt.show()
# Out:
# /mnt/hdd/eric/.conda/envs/8.tmp/lib/python3.8/site-packages/PIL/Image.py:3176: DecompressionBombWarning: Image size (1008521856 pixels) exceeds limit of 933120000 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# #-------------- 0.0043
# #-------------- 0.0086
# #-------------- 0.0129
# #-------------- 0.0172
# #-------------- 0.0216
# #-------------- 0.0259
# #-------------- 0.0302
# #-------------- 0.0345
# #-------------- 0.0388
# #-------------- 0.0431
# #-------------- 0.0474
# #-------------- 0.0517
# #-------------- 0.0560
# #-------------- 0.0603
# #-------------- 0.0647
# #-------------- 0.0690
# #-------------- 0.0733
# #-------------- 0.0776
# #-------------- 0.0819
# #-------------- 0.0862
# #-------------- 0.0905
# #-------------- 0.0948
# #-------------- 0.0991
# #-------------- 0.1034
# #-------------- 0.1078
# #-------------- 0.1121
# #-------------- 0.1164
# #-------------- 0.1207
# #-------------- 0.1250
# #-------------- 0.1293
# #-------------- 0.1336
# #-------------- 0.1379
# #-------------- 0.1422
# #-------------- 0.1466
# #-------------- 0.1509
# #-------------- 0.1552
# #-------------- 0.1595
# #-------------- 0.1638
# #-------------- 0.1681
# #-------------- 0.1724
# #-------------- 0.1767
# #-------------- 0.1810
# #-------------- 0.1853
# #-------------- 0.1897
# #-------------- 0.1940
# #-------------- 0.1983
# #-------------- 0.2026
# #-------------- 0.2069
# #-------------- 0.2112
# #-------------- 0.2155
# #-------------- 0.2198
# #-------------- 0.2241
# #-------------- 0.2284
# #-------------- 0.2328
# #-------------- 0.2371
# #-------------- 0.2414
# #-------------- 0.2457
# #-------------- 0.2500
# #-------------- 0.2543
# #-------------- 0.2586
# #-------------- 0.2629
# #-------------- 0.2672
# #-------------- 0.2716
# #-------------- 0.2759
# #-------------- 0.2802
# #-------------- 0.2845
# #-------------- 0.2888
# #-------------- 0.2931
# #-------------- 0.2974
# #-------------- 0.3017
# #-------------- 0.3060
# #-------------- 0.3103
# #-------------- 0.3147
# #-------------- 0.3190
# #-------------- 0.3233
# #-------------- 0.3276
# #-------------- 0.3319
# #-------------- 0.3362
# #-------------- 0.3405
# #-------------- 0.3448
# #-------------- 0.3491
# #-------------- 0.3534
# #-------------- 0.3578
# #-------------- 0.3621
# #-------------- 0.3664
# #-------------- 0.3707
# #-------------- 0.3750
# #-------------- 0.3793
# #-------------- 0.3836
# #-------------- 0.3879
# #-------------- 0.3922
# #-------------- 0.3966
# #-------------- 0.4009
# #-------------- 0.4052
# #-------------- 0.4095
# #-------------- 0.4138
# #-------------- 0.4181
# #-------------- 0.4224
# #-------------- 0.4267
# #-------------- 0.4310
# #-------------- 0.4353
# #-------------- 0.4397
# #-------------- 0.4440
# #-------------- 0.4483
# #-------------- 0.4526
# #-------------- 0.4569
# #-------------- 0.4612
# #-------------- 0.4655
# #-------------- 0.4698
# #-------------- 0.4741
# #-------------- 0.4784
# #-------------- 0.4828
# #-------------- 0.4871
# #-------------- 0.4914
# #-------------- 0.4957
# #-------------- 0.5000
# #-------------- 0.5043
# #-------------- 0.5086
# #-------------- 0.5129
# #-------------- 0.5172
# #-------------- 0.5216
# #-------------- 0.5259
# #-------------- 0.5302
# #-------------- 0.5345
# #-------------- 0.5388
# #-------------- 0.5431
# #-------------- 0.5474
# #-------------- 0.5517
# #-------------- 0.5560
# #-------------- 0.5603
# #-------------- 0.5647
# #-------------- 0.5690
# #-------------- 0.5733
# #-------------- 0.5776
# #-------------- 0.5819
# #-------------- 0.5862
# #-------------- 0.5905
# #-------------- 0.5948
# #-------------- 0.5991
# #-------------- 0.6034
# #-------------- 0.6078
# #-------------- 0.6121
# #-------------- 0.6164
# #-------------- 0.6207
# #-------------- 0.6250
# #-------------- 0.6293
# #-------------- 0.6336
# #-------------- 0.6379
# #-------------- 0.6422
# #-------------- 0.6466
# #-------------- 0.6509
# #-------------- 0.6552
# #-------------- 0.6595
# #-------------- 0.6638
# #-------------- 0.6681
# #-------------- 0.6724
# #-------------- 0.6767
# #-------------- 0.6810
# #-------------- 0.6853
# #-------------- 0.6897
# #-------------- 0.6940
# #-------------- 0.6983
# #-------------- 0.7026
# #-------------- 0.7069
# #-------------- 0.7112
# #-------------- 0.7155
# #-------------- 0.7198
# #-------------- 0.7241
# #-------------- 0.7284
# #-------------- 0.7328
# #-------------- 0.7371
# #-------------- 0.7414
# #-------------- 0.7457
# #-------------- 0.7500
# #-------------- 0.7543
# #-------------- 0.7586
# #-------------- 0.7629
# #-------------- 0.7672
# #-------------- 0.7716
# #-------------- 0.7759
# #-------------- 0.7802
# #-------------- 0.7845
# #-------------- 0.7888
# #-------------- 0.7931
# #-------------- 0.7974
# #-------------- 0.8017
# #-------------- 0.8060
# #-------------- 0.8103
# #-------------- 0.8147
# #-------------- 0.8190
# #-------------- 0.8233
# #-------------- 0.8276
# #-------------- 0.8319
# #-------------- 0.8362
# #-------------- 0.8405
# #-------------- 0.8448
# #-------------- 0.8491
# #-------------- 0.8534
# #-------------- 0.8578
# #-------------- 0.8621
# #-------------- 0.8664
# #-------------- 0.8707
# #-------------- 0.8750
# #-------------- 0.8793
# #-------------- 0.8836
# #-------------- 0.8879
# #-------------- 0.8922
# #-------------- 0.8966
# #-------------- 0.9009
# #-------------- 0.9052
# #-------------- 0.9095
# #-------------- 0.9138
# #-------------- 0.9181
# #-------------- 0.9224
# #-------------- 0.9267
# #-------------- 0.9310
# #-------------- 0.9353
# #-------------- 0.9397
# #-------------- 0.9440
# #-------------- 0.9483
# #-------------- 0.9526
# #-------------- 0.9569
# #-------------- 0.9612
# #-------------- 0.9655
# #-------------- 0.9698
# #-------------- 0.9741
# #-------------- 0.9784
# #-------------- 0.9828
# #-------------- 0.9871
# #-------------- 0.9914
# #-------------- 0.9957
# #-------------- 1.0000

# %%
# # Compare Experiment No masking 

# # visualize the result 
# # original image 
# img_path = args.img_path
# img_ = Image.open(img_path)

# plt.figure(figsize=(18,18))
# plt.imshow(img_)
# ax = plt.gca()

# #------------------------------------
# # Bbox 
# bboxes_ = [] 
# cnt = 0
# box_cnt = 0


# # No_masked
# for i,row in M_.iterrows():
#     x = row['bbox x coord']
#     y = row['bbox y coord']
#     width = row['bbox width']
#     height = row['bbox height']
#     angle_ = row['bbox angle']
    
#     box_cnt+=1
#     print(f"#-------------- {box_cnt / len(M_):.4f}")
#     path_obj = patches.Rectangle((x-width*0.5,y-height*0.5), width, height, linewidth=0.1, edgecolor="red", fill=False,
#                                 rotation_point="center",
#                                 angle=angle_*180/np.pi)
    
#     ax.add_patch(path_obj)
# #------------------------------------


# plt.savefig(args.img_path.replace(".png" ,"_output_v2_1207_no_masking.png"),dpi =1200 )
# plt.show()

# %%
# M_['land_included'] = tmp_1

# %%
args.final_merge.replace("_PS.csv", "_PS_masking.csv")
# Out:
# '/mnt/hdd/eric/.tmp_ipy/00.Data/AO/0-Pusan-2023-AO/C1_20230116015105_10110_00006119_L1G_PS/0-Pusan-2023-AO_3_C1_20230116015105_10110_00006119_L1G.csv'

# %%
# import os 
# M_.to_csv(os.path.join("/mnt/hdd/eric/.tmp_ipy/00.Data/tmp_","test1.csv"),index=False )

# %%
# import os 
# M_.to_csv(args.final_merge,index=False )
